# %% [markdown]
# # **Function Arguments / Parameters**
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **You can call a function by using the following types of formal arguments-**
#
#
# > ✔	Required arguments
#
# > ✔	Keyword arguments
#
# > ✔	Default arguments
#
# > ✔	Variable-length arguments

# %% [markdown]
# # **Required Arguments**
#
# ---

# %% [markdown]
# >**Required arguments are the arguments passed to a function *in correct positional order***.
#
# >**The *number of arguments* in the function call should match exactly with the function definition.**

# %% [markdown]
# **Example: 1**
#
# ---

# %%
def printme( str, name ):
    "This prints a passed string into this function"
    print (str , name)
    return

# Now you can call printme function
printme('This is me, ', 'My name is Rajit.')
printme("This is me with name")
printme()
# Out:
# This is me,  My name is Rajit.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-18085ad573da> in <cell line: 8>()
#       6 # Now you can call printme function
#       7 printme('This is me, ', 'My name is Rajit.')
# ----> 8 printme("This is me with name")
#       9 printme()
#
# TypeError: printme() missing 1 required positional argument: 'name'

# %% [markdown]
# **Exercise: 1**
#
# Write two functions named printInfo() and purchaseList().
#
# First function will have two required arguments name and customerID.
#
# Second function will have three required arguments product1Price, product2Price, product3Price.
#
# Pass these functions values. First function will print the given data and second function will calculate the total price. Then print all the prices and total price.

# %%
# Write your code here..

# %% [markdown]
# **Exercise: 2**
#
#
# What would be the output of the following program? will there be any error? If yes, why?

# %%
def getInformation():
  id = int(input('ID: '))
  cgpa = float(input('CGPA: '))
  return [id, cgpa]

def calculateGrade(stID, stCGPA):
  print('Student id: ', stID)
  print('Stdent CGPA: ', stCGPA)
  if stCGPA > 3.5:
    print('Student Grade: Distinction')
  else:
    print('No distinction')

x,y = getInformation()

calculateGrade()
#correct way: calculateGrade(x,y)
# Out:
# ID: 123
# CGPA: 3.5
# [123, 3.5]
# Student id:  123
# Stdent CGPA:  3.5
# No distinction

# %%
# Corrected program
#---------------------------------------
def getInformation():
  id = int(input('ID: '))
  cgpa = float(input('CGPA: '))
  return id, cgpa

def calculateGrade(stID, stCGPA):
  print('Student id: ', stID)
  print('Stdent CGPA: ', stCGPA)
  if stCGPA > 3.5:
    print('Student Grade: Distinction')
  else:
    print('No distinction')

stInfo = getInformation()
calculateGrade(stInfo[0], stInfo[1])

# %% [markdown]
# # **Keyword Arguments**
#
# ---

# %% [markdown]
# >**Keyword arguments are related to the function calls.**
#
# >**When use keyword arguments in a function call, the caller identifies the arguments by the parameter name.**

# %% [markdown]
# **Example: 2**
#
# ---

# %%
def printinfo( name, age ):
    "This prints a passed info into this function"
    print ("Name: ", name)
    print ("Age ", age)
    return

# Now you can call printinfo function
printinfo( age=50, name="miki" )
printinfo("miki", age=50)
printinfo(age=50, "miki") #-> will show error
printinfo(age = 30) #-> will show error
# Out:
# Name:  miki
# Age  50
# Name:  miki
# Age  50

# %% [markdown]
# **Exercise: 3 Keyword arguments are also Required arguments - True / False?**

# %% [markdown]
# **Exercise: 4**
#
# What would be the output of the following program? will there be any error? If yes, why?

# %%
def calculteCGPA( gpa1, gpa2, name):

    print (f"{name}: {gpa1}, {gpa2}")
    cgpa = (gpa1 + gpa2) / 2
    print ("Your CGPA: ", cgpa)
    return

# Calling the function
calculteCGPA(3.11, 4.22)
calculteCGPA(gpa1=3.44, "miki", gpa2 = 3.67 )
calculteCGPA(gpa2 = 3.11, name = 'Tom')
# Out:
# miki: 3.44, 3.67
# Your CGPA:  3.5549999999999997

# %% [markdown]
# **Exerise: 5 Why do you think keyword arguments are better approach than Required arguments?**

# %% [markdown]
# # **Default Arguments**
#
# ---

# %% [markdown]
# **A default argument is an argument that assumes a default value if a value is not provided in the function call for that argument.**

# %% [markdown]
# **Example: 3**
#
# ---

# %%
def printinfo( name = 'Rajit', age = 35):             # default arguments
    "This prints a passed info into this function"
    print ("Name: ", name)
    print ("Age ", age)


# Now you can call printinfo function
printinfo( age=50, name="miki" )
printinfo( name = 'Samah')
printinfo()
# Out:
# Name:  miki
# Age  50
# Name:  Samah
# Age  35
# Name:  Rajit
# Age  35

# %% [markdown]
# **Exercise 6: What is the difference between Required arguments and Default Arguments?**

# %% [markdown]
# **Exercise 7: Given an example scenario where you will use default arguments for the function parameter. Write a sample program for that scenario using default argument.**

# %%
# Your code should go here...
# Consder that you have a function that calculates and pays interest on a given deposit amount, and the minimum interest rate is .5% for any amount in the bank.
# This function will take account balance, interest rate and customer id as parameters, then calculate the interest.
# Then prints the principal amount, interest amount, total payable and customer id.

# %% [markdown]
# # **Variable-Length Arguments**
#
# ---

# %% [markdown]
# > ✔	Some time we need to pass variable number of arguments to the function.
#
# > ✔	These arguments are called variable-length arguments.
#
# > ✔	An asterisk (*) is placed before the variable name. It holds the values as tuple.

# %% [markdown]
# **Example: 4**
#
# ---

# %%
def printinfo( arg1,*vartuple ):
    "This prints a variable passed arguments"
    print(type(vartuple))
    print(vartuple)
    print ('Required argument: ', arg1)

    print ('variable arguments: ')
    for var in vartuple:
        print (var)
    return


printinfo('This is Syeed', *[1007, 'CGPA: 3.95', 'syeed@gmail.com']) # Cant pass list directly
# Out:
# <class 'tuple'>
# (1007, 'CGPA: 3.95', 'syeed@gmail.com')
# Required argument:  This is Syeed
# variable arguments:
# 1007
# CGPA: 3.95
# syeed@gmail.com

# %% [markdown]
# **Example 5:**
#
# ---

# %%
def print_details(*args):
  print(args)
  for value in args:
      print(value)

name = input("Enter your name: ")
age = input("Enter your age: ")
email = input("Enter your email: ")

print_details(name, age, email)
# Out:
# Enter your name: Mahbub
# Enter your age: 27
# Enter your email: abc
# ('Mahbub', '27', 'abc')
# Mahbub
# 27
# abc

# %% [markdown]
# **Example 6:**
#
# ---

# %%
def find_sum_max(*args):

    sum = 0
    for n in args:
      sum += n

    max_value = max(args)

    return [sum, max_value]

numbers = input("Enter numbers separated by spaces: ")
numbers_list = [int(num) for num in numbers.split()]
print(numbers_list)

result = find_sum_max(*numbers_list)         # passing a list to var-arg

print()
print("The sum is:", result[0])
print("The maximum number is:", result[1])
# Out:
# Enter numbers separated by spaces: 1 2 3 4
# [1, 2, 3, 4]
#
# The sum is: 10
# The maximum number is: 4

# %% [markdown]
# **Exercise 7: Write down few scenarios where you will use variable length argument for your function.**

# %% [markdown]
# **Exercise 8: Variable length arguments are Required arguments - True / False?**

# %% [markdown]
# **Exercise 9: What is/are the advantage(s) of variable length arguments over keyword arguments?**

# %% [markdown]
# **Exercise 10: Implement the following pogram using variable length argument.**
#
# > a. Take numbers as input that are separated by space.
#
# > b. Create a list of integers from the input.
#
# > c. Pass the list as variable length argument to the follwoing function-
#
# > d. Write a function name calculate() that take a variable length argument as paramenter and does the followings -
#
# >> d1. Calculate the sum of the numbers.
#
# >> d2. Calculate the average of the numbers.
#
# >> d3. Find the maximum number.
#
# >> d4. Find the minimum number.
#
# >> d5. Return all the four values as list.
#
# > e. Get the list retured by the calculate() function and print all the values with appropriate message using a single print() function.

# %%
# your code goes here....
